# %% [markdown]
# ### Unit 4 Home Work Assignment: Pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# #### Reading the input CSV files

# %%
# importing data
csvpath1 = Path('C:/Users/Endalkachew Desta/downloads/Resources/aapl_historical.csv')
csvpath2 = Path('C:/Users/Endalkachew Desta/downloads/Resources/algo_returns.csv')
csvpath3 = Path('C:/Users/Endalkachew Desta/downloads/Resources/cost_historical.csv')
csvpath4 = Path('C:/Users/Endalkachew Desta/downloads/Resources/goog_historical.csv')
csvpath5 = Path('C:/Users/Endalkachew Desta/downloads/Resources/sp500_history.csv')
csvpath6 = Path('C:/Users/Endalkachew Desta/downloads/Resources/whale_returns.csv')

# %%
# reading the data
aapl_hist_data = pd.read_csv(csvpath1)
algo_return_data = pd.read_csv(csvpath2)
cost_hist_data = pd.read_csv(csvpath3)
goog_hist_data = pd.read_csv(csvpath4)
sp500_his_data = pd.read_csv(csvpath5)
whale_returns_data = pd.read_csv(csvpath6)

# %%
# to data frame
df1 = pd.DataFrame(aapl_hist_data)
df2 = pd.DataFrame(algo_return_data)
df3 = pd.DataFrame(cost_hist_data)
df4 = pd.DataFrame(goog_hist_data)
df5 = pd.DataFrame(sp500_his_data)
df6 = pd.DataFrame(whale_returns_data)
df6.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %% [markdown]
# ### Setting the datetime index

# %%
# formatting the date time and assigning the index
df1['DateTime'] = pd.to_datetime(df1['Trade DATE'])
df2['DateTime'] = pd.to_datetime(df2['Date'])
df3['DateTime'] = pd.to_datetime(df3['Trade DATE'])
df4['DateTime'] = pd.to_datetime(df4['Trade DATE'])
df5['DateTime'] = pd.to_datetime(df5['Date'])
df6['DateTime'] = pd.to_datetime(df6['Date'])

df1 = df1.set_index(['DateTime'])
df2 = df2.set_index(['DateTime'])
df3 = df3.set_index(['DateTime'])
df4 = df4.set_index(['DateTime'])
df5 = df5.set_index(['DateTime'])
df6 = df6.set_index(['DateTime'])

del df1['Trade DATE']
del df2['Date']
del df3['Trade DATE']
del df4['Trade DATE']
del df5['Date']
del df6['Date']
df6.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# DateTime
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %% [markdown]
# #### Removing the dollar sign from df5 and setting the data type to float

# %%
# removing $ sign
df5['Close'] = df5['Close'].str.replace('$', '')
df5['Close'] = df5['Close'].astype(float)
df5.head()
# Out:
#               Close
# DateTime
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %% [markdown]
# ### Detecting null entries

# %%
# locating columns with null entries
df1_null = df1[df1.isnull().any(axis=1)]
df1_null.head()
df2_null = df2[df2.isnull().any(axis=1)]
df2_null.head()
df3_null = df3[df3.isnull().any(axis=1)]
df3_null.head()
df4_null = df4[df4.isnull().any(axis=1)]
df4_null.head()
df5_null = df5[df5.isnull().any(axis=1)]
df5_null.head()
df6_null = df6[df6.isnull().any(axis=1)]
df6_null.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-03-02                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# DateTime
# 2015-03-02                          NaN                     NaN

# %% [markdown]
# #### Removing rows with null entries

# %%
#Clear entries with null imputs
df1 = df1.dropna()
df1 =df1.sort_index()
df2 = df2.dropna()
df2 =df2.sort_index()
df3 = df3.dropna()
df3 =df3.sort_index()
df4 = df4.dropna()
df4 =df4.sort_index()
df5 = df5.dropna()
#df5.reset_index(drop=True)
df6 = df6.dropna()
df6 =df6.sort_index()

# %% [markdown]
# #### Convert SP500 data to daily returns format

# %%
# changing SP500 data to daily returns
df5['SP500Daily'] = df5.pct_change()

df5 = df5.dropna()
df5.reset_index()

del df5['Close']

df5 = df5.sort_index()

df5.head()
# Out:
#             SP500Daily
# DateTime
# 2012-10-01   -0.000872
# 2012-10-02   -0.003611
# 2012-10-03   -0.007123
# 2012-10-04    0.000322
# 2012-10-05    0.003469

# %% [markdown]
# #### Concatinating and sorting Sp500, Algo_Returns and Whale_returns data

# %%
# concatinating Whale and Algo data
joined_data=pd.concat([df6, df2, df5],axis='columns',join='inner')

joined_data = joined_data.sort_index()
joined_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500Daily
# DateTime
# 2015-03-03 -0.000949    0.004408
# 2015-03-04  0.002416   -0.001195
# 2015-03-05  0.004323    0.014378
# 2015-03-06 -0.011460   -0.003929
# 2015-03-09  0.001303    0.017254

# %%
# cummulative returns
cum_returns=(joined_data+1).cumprod()
cum_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2  SP500Daily
# DateTime
# 2015-03-03  0.999051    1.004408
# 2015-03-04  1.001464    1.003208
# 2015-03-05  1.005794    1.017632
# 2015-03-06  0.994267    1.013634
# 2015-03-09  0.995563    1.031123

# %% [markdown]
# #### Plot of the daily returns and the cummulative returns

# %%
# Plot
import matplotlib.pyplot as plt
joined_data.plot(y = ['Algo 1','SP500Daily'],title='Algo1 vs Sp500 Daily Returns',grid=True)
joined_data.plot(y = ['Algo 2','SP500Daily'],title='Algo2 vs Sp500 Daily Returns',grid=True)
joined_data.plot(y = ['SOROS FUND MANAGEMENT LLC','SP500Daily'],title='Soros vs Sp500 Daily Returns',grid=True)
#joined_data.plot(y = ['PAULSON & CO.INC.','SP500Daily'],title='Paulson vs Sp500 Daily Returns',grid=True)
joined_data.plot(y = ['TIGER GLOBAL MANAGEMENT LLC','SP500Daily'],title='Tiger Vs SP500 Daily Returns',grid=True)
joined_data.plot(y = ['BERKSHIRE HATHAWAY INC','SP500Daily'],title='Berkshire vs Sp500 Daily Returns',grid=True)
joined_data.plot(title='All protfolios vs Sp500 Daily Returns',grid=True)
(joined_data+1).cumprod().plot(grid=True,title='Cumulative Returns')
joined_data.plot.box(grid=True,rot=75)

plt.show()

# %% [markdown]
# #### Basic stat info of joined data

# %%
# stat data of the joined data
joined_data.describe()
# Out:
#        SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# count                1042.000000         1042.000000
# mean                    0.000171           -0.000217
# std                     0.007896            0.007026
# min                    -0.032711           -0.032099
# 25%                    -0.003641           -0.004044
# 50%                     0.000517            0.000000
# 75%                     0.004320            0.003629
# max                     0.042977            0.029338
#
#        TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC       Algo 1  \
# count                  1042.000000             1042.000000  1042.000000
# mean                     -0.000089                0.000494     0.000658
# std                       0.010897                0.012919     0.007623
# min                      -0.139820               -0.066505    -0.030951
# 25%                      -0.004792               -0.005655    -0.003257
# 50%                       0.000313                0.000726     0.000069
# 75%                       0.005233                0.007565     0.003874
# max                       0.080705                0.061341     0.050735
#
#             Algo 2   SP500Daily
# count  1042.000000  1042.000000
# mean      0.000254    -0.000281
# std       0.008341     0.008587
# min      -0.036937    -0.047250
# 25%      -0.003799    -0.004456
# 50%       0.000698    -0.000450
# 75%       0.005226     0.002881
# max       0.030822     0.042730

# %% [markdown]
# ### Annual Returns

# %%
# calculating annual returns
ydata = joined_data.resample('Y').apply(lambda x: x[-1])
Annual_returns = ydata.pct_change()
Annual_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-12-31                        NaN                 NaN
# 2016-12-31                  -0.494498           -2.644008
# 2017-12-31                  -2.681559           -1.124398
# 2018-12-31                   2.213671           -9.602091
# 2019-12-31                  -1.366303           -2.287554
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2015-12-31                          NaN                     NaN       NaN
# 2016-12-31                    -0.431582               -0.021571 -1.214446
# 2017-12-31                    -0.558570               -0.840066 -1.834985
# 2018-12-31                     0.483033               -6.598139  1.872131
# 2019-12-31                    -0.108576               -1.190981 -0.900037
#
#               Algo 2  SP500Daily
# DateTime
# 2015-12-31       NaN         NaN
# 2016-12-31 -0.730535   -1.541460
# 2017-12-31  5.606671   -0.021409
# 2018-12-31 -2.048299   -0.846155
# 2019-12-31 -1.337046    5.917372

# %%
joined_data.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500Daily                     0.136313
# dtype: float64

# %% [markdown]
# ### Rolling Stat

# %% [markdown]
# ##### Rolling Standard Deviation

# %%
# Rolling std
Rolling_STD = joined_data.rolling(21).std()
null_rolling = Rolling_STD.isnull().sum(axis=0)
null_rolling
Rolling_STD.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2019-04-15                   0.006804            0.006225
# 2019-04-16                   0.006711            0.006224
# 2019-04-17                   0.006773            0.006370
# 2019-04-18                   0.006633            0.006303
# 2019-04-22                   0.005915            0.006400
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2019-04-15                     0.007525                0.009729  0.005496
# 2019-04-16                     0.007532                0.009731  0.005760
# 2019-04-17                     0.007574                0.009485  0.006229
# 2019-04-18                     0.007328                0.009475  0.005834
# 2019-04-22                     0.006197                0.009104  0.005831
#
#               Algo 2  SP500Daily
# DateTime
# 2019-04-15  0.007572    0.006532
# 2019-04-16  0.007053    0.006571
# 2019-04-17  0.007165    0.006505
# 2019-04-18  0.007172    0.006137
# 2019-04-22  0.007113    0.004302

# %% [markdown]
# ##### Rolling Correlation and simple correlation

# %%
# Rolling correlation
Rolling_correlat = joined_data.rolling(21).corr(joined_data['SP500Daily'])
Rolling_correlat.tail(50)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# SP500Daily                                    0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
# SP500Daily                                     -0.001505
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# PAULSON & CO.INC.                          0.545451  0.268631  0.678085
# TIGER GLOBAL MANAGEMENT LLC                0.424125  0.164114  0.507160
# BERKSHIRE HATHAWAY INC                     1.000000  0.291678  0.687756
# Algo 1                                     0.291678  1.000000  0.287852
# Algo 2                                     0.687756  0.287852  1.000000
# SP500Daily                                -0.013856 -0.033963 -0.002192
#
#                              SP500Daily
# SOROS FUND MANAGEMENT LLC      0.000574
# PAULSON & CO.INC.              0.013549
# TIGER GLOBAL MANAGEMENT LLC   -0.001505
# BERKSHIRE HATHAWAY INC        -0.013856
# Algo 1                        -0.033963
# Algo 2                        -0.002192
# SP500Daily                     1.000000

# %% [markdown]
# ##### Correlation plot

# %%
# plot
correlat.plot(grid=True,rot=30,title='Correlation function',xlabel='Portfolio',ylabel='Corr')
Rolling_correlat.plot(grid=True,title='Rolling correlation',xlabel='Time',ylabel='Corr')
Rolling_STD.plot(grid=True,title='Rolling STD of W=21',xlabel='Time',ylabel='STD')
# Out:
# <AxesSubplot:title={'center':'Rolling STD of W=21'}, xlabel='Time', ylabel='STD'>

# %%
joined_data.columns
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2', 'SP500Daily'],
#       dtype='object')

# %% [markdown]
# #### Rolling Beta: Rolling Variance

# %%
# calculating rolling variance of SP500
rollingVar = joined_data['SP500Daily'].rolling(60).var()
rollingVar
# Out:
# DateTime
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15    0.000041
# 2019-04-16    0.000037
# 2019-04-17    0.000037
# 2019-04-18    0.000037
# 2019-04-22    0.000037
# Name: SP500Daily, Length: 1042, dtype: float64

# %% [markdown]
# #### Rolling Covariance

# %%
# calculating rolling covariance
rollingCov = joined_data['Algo 1'].rolling(60).cov(joined_data['SP500Daily'])
rollingCov
# Out:
# DateTime
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15   -0.000005
# 2019-04-16   -0.000004
# 2019-04-17   -0.000004
# 2019-04-18   -0.000004
# 2019-04-22   -0.000004
# Length: 1042, dtype: float64

# %% [markdown]
# #### Rolling Beta

# %%
# calculating rolling beta
rolling_beta = rollingCov/rollingVar
rolling_beta
# Out:
# DateTime
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15   -0.116546
# 2019-04-16   -0.102774
# 2019-04-17   -0.101901
# 2019-04-18   -0.103039
# 2019-04-22   -0.113498
# Length: 1042, dtype: float64

# %%
# rolling beta plot
rolling_beta.plot(rot=75,grid=True,title='Rolling Beta of W=60',xlabel='Time',ylabel='Beta')
# Out:
# <AxesSubplot:title={'center':'Rolling Beta of W=60'}, xlabel='Time', ylabel='Beta'>

# %% [markdown]
# #### Exponentially Weighted Moving Average

# %%
# EWM calculation
ewma = joined_data.ewm(halflife = 21).mean()
ewma.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.000511           -0.000802
# 2015-03-05                   0.001718            0.000878
# 2015-03-06                  -0.000808           -0.000291
# 2015-03-09                  -0.000511            0.000673
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.001532               -0.001089 -0.005320
# 2015-03-05                    -0.000193                0.001603 -0.003817
# 2015-03-06                    -0.002369               -0.002256 -0.004116
# 2015-03-09                    -0.000616               -0.002128 -0.004400
#
#               Algo 2  SP500Daily
# DateTime
# 2015-03-03 -0.000949    0.004408
# 2015-03-04  0.000761    0.001560
# 2015-03-05  0.001988    0.005975
# 2015-03-06 -0.001542    0.003375
# 2015-03-09 -0.000935    0.006337

# %%
# ewm plot
ewma.plot(rot=75,grid=True,title='Expo. weighted MA half life=21',xlabel='Time')
# Out:
# <AxesSubplot:title={'center':'Expo. weighted MA half life=21'}, xlabel='Time'>

# %% [markdown]
# #### Sharp Ratio

# %%
# calculating sharpe ratio
sharpe_ratio = (joined_data.mean()*252-0.0025)/(joined_data.std()*np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.322949
# PAULSON & CO.INC.             -0.513839
# TIGER GLOBAL MANAGEMENT LLC   -0.144638
# BERKSHIRE HATHAWAY INC         0.594552
# Algo 1                         1.348929
# Algo 2                         0.465454
# SP500Daily                    -0.536922
# dtype: float64

# %%
# sharpe ratio bar plot
sharpe_ratio.plot(rot=75,grid=True,kind='bar',xlabel='Portfolio',ylabel='Sharpe Ratio')
# Out:
# <AxesSubplot:xlabel='Portfolio', ylabel='Sharpe Ratio'>

# %% [markdown]
# ####### Algo 1 outperformed all other portfolios and Algo 2 outperformed all but Berkshire Hathaway.

# %% [markdown]
# ## Custom Portfolio

# %%
# Import the data
csvpath7=Path('C:/Users/Endalkachew Desta/Downloads/tsla.csv')
csvpath8=Path('C:/Users/Endalkachew Desta/Downloads/goog.csv')
csvpath9=Path('C:/Users/Endalkachew Desta/Downloads/ual.csv')

# %%
#Read the imported data
tsla = pd.read_csv(csvpath7)
goog = pd.read_csv(csvpath8)
ual = pd.read_csv(csvpath9)
#To dataframe
TSLA = pd.DataFrame(tsla)
GOOG = pd.DataFrame(goog)
UAL = pd.DataFrame(ual)
# Date time formatting
TSLA['DateTime'] = pd.to_datetime(TSLA['Date'])
GOOG['DateTime'] = pd.to_datetime(GOOG['Date'])
UAL['DateTime'] = pd.to_datetime(UAL['Date'])

TSLA = TSLA.rename(columns = {"Close":"TSLA_Close"})
GOOG = GOOG.rename(columns = {"Close":"GOOG_Close"})
UAL = UAL.rename(columns = {"Close":"UAL_Close"})

TSLA['DateTime'] = TSLA['DateTime'].apply(lambda x: x.date())
del TSLA['Date']
TSLA = TSLA.set_index(['DateTime'])

GOOG['DateTime'] = GOOG['DateTime'].apply(lambda x: x.date())
del GOOG['Date']
GOOG = GOOG.set_index(['DateTime'])

UAL['DateTime'] = UAL['DateTime'].apply(lambda x: x.date())
del UAL['Date']
UAL = UAL.set_index(['DateTime'])
#concatinating the input data
my_port=pd.concat([TSLA, GOOG, UAL],axis='columns',join='inner')
my_port.head()
# Out:
#             TSLA_Close  GOOG_Close  UAL_Close
# DateTime
# 2014-05-28       42.05      560.14      44.89
# 2014-05-29       42.05      558.55      44.60
# 2014-05-30       41.55      558.36      44.37
# 2014-06-02       40.94      552.41      46.70
# 2014-06-03       40.99      543.45      47.51

# %%
# calcualting daily returns and sorting
my_port_daily = my_port.pct_change()
my_port_daily = my_port_daily.dropna()
my_port_daily.sort_index()
my_port_daily.head()
# Out:
#             TSLA_Close  GOOG_Close  UAL_Close
# DateTime
# 2014-05-29    0.000000   -0.002839  -0.006460
# 2014-05-30   -0.011891   -0.000340  -0.005157
# 2014-06-02   -0.014681   -0.010656   0.052513
# 2014-06-03    0.001221   -0.016220   0.017345
# 2014-06-04   -0.004635   -0.000515  -0.013471

# %%
# calculating the weighted returns
weighted_ret = (1/3)*my_port_daily
weighted_ret.head()
# Out:
#             TSLA_Close  GOOG_Close  UAL_Close
# DateTime
# 2014-05-29    0.000000   -0.000946  -0.002153
# 2014-05-30   -0.003964   -0.000113  -0.001719
# 2014-06-02   -0.004894   -0.003552   0.017504
# 2014-06-03    0.000407   -0.005407   0.005782
# 2014-06-04   -0.001545   -0.000172  -0.004490

# %%
# concatinating the new input data with the origional
Concat_data = pd.concat([joined_data,my_port_daily],axis='columns',join='inner')
Concat_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2  SP500Daily  TSLA_Close  GOOG_Close  UAL_Close
# DateTime
# 2015-03-03 -0.000949    0.004408    0.011148    0.004019   0.032780
# 2015-03-04  0.002416   -0.001195    0.014533   -0.000472  -0.004783
# 2015-03-05  0.004323    0.014378   -0.008891    0.003428  -0.010922
# 2015-03-06 -0.011460   -0.003929   -0.033641   -0.013298  -0.018404
# 2015-03-09  0.001303    0.017254   -0.015472    0.002049  -0.007800
# ...              ...         ...         ...         ...        ...
# 2019-04-15 -0.004572   -0.000509   -0.004856    0.002652  -0.011346
# 2019-04-16  0.002899    0.002279    0.026089    0.004938   0.007690
# 2019-04-17 -0.005228   -0.001577   -0.007682    0.007505   0.047787
# 2019-04-18 -0.001229   -0.001011    0.007373    0.000024  -0.010758
# 2019-04-22 -0.001936   -0.008764   -0.038426    0.010086  -0.008156
#
# [1042 rows x 10 columns]

# %%
concat_data_corr = Concat_data.corr()
concat_data_corr
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# SP500Daily                                    0.000574            0.013549
# TSLA_Close                                    0.359045            0.262447
# GOOG_Close                                    0.567704            0.431741
# UAL_Close                                     0.439628            0.337391
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# Algo 2                                          0.507160
# SP500Daily                                     -0.001505
# TSLA_Close                                      0.245276
# GOOG_Close                                      0.410375
# UAL_Close                                       0.284402
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.754157  0.320901  0.826730
# PAULSON & CO.INC.                          0.545451  0.268631  0.678085
# TIGER GLOBAL MANAGEMENT LLC                0.424125  0.164114  0.507160
# BERKSHIRE HATHAWAY INC                     1.000000  0.291678  0.687756
# Algo 1                                     0.291678  1.000000  0.287852
# Algo 2                                     0.687756  0.287852  1.000000
# SP500Daily                                -0.013856 -0.033963 -0.002192
# TSLA_Close                                 0.392969  0.135093  0.346918
# GOOG_Close                                 0.646949  0.203030  0.530363
# UAL_Close                                  0.384984  0.154045  0.453732
#
#                              SP500Daily  TSLA_Close  GOOG_Close  UAL_Close
# SOROS FUND MANAGEMENT LLC      0.000574    0.359045    0.567704   0.439628
# PAULSON & CO.INC.              0.013549    0.262447    0.431741   0.337391
# TIGER GLOBAL MANAGEMENT LLC   -0.001505    0.245276    0.410375   0.284402
# BERKSHIRE HATHAWAY INC        -0.013856    0.392969    0.646949   0.384984
# Algo 1                        -0.033963    0.135093    0.203030   0.154045
# Algo 2                        -0.002192    0.346918    0.530363   0.453732
# SP500Daily                     1.000000    0.049436   -0.044723   0.015073
# TSLA_Close                     0.049436    1.000000    0.298542   0.164659
# GOOG_Close                    -0.044723    0.298542    1.000000   0.316449
# UAL_Close                      0.015073    0.164659    0.316449   1.000000

# %%
# calculating correlation 
my_port_corr = my_port_daily.corr()
my_port_corr
# Out:
#             TSLA_Close  GOOG_Close  UAL_Close
# TSLA_Close    1.000000    0.295815   0.170895
# GOOG_Close    0.295815    1.000000   0.287706
# UAL_Close     0.170895    0.287706   1.000000

# %%
# correlation data plot
#my_port_corr.plot(rot=75,grid=True,kind='bar',xlabel='Portfolio',ylabel='Correlation')
sns.heatmap(concat_data_corr,annot=True, fmt=" ")
grid=True
#sns.heatmap(my_port_corr,annot=True, fmt=" ")#,title='custom portfolio corr')

# %%
# calculating rolling std
my_port_Rstd = my_port_daily.rolling(21).std()
my_port_Rstd.tail()

concat_data_Rstd = Concat_data.rolling(21).std()
concat_data_Rstd.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# DateTime
# 2019-04-15                   0.006804            0.006225
# 2019-04-16                   0.006711            0.006224
# 2019-04-17                   0.006773            0.006370
# 2019-04-18                   0.006633            0.006303
# 2019-04-22                   0.005915            0.006400
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# DateTime
# 2019-04-15                     0.007525                0.009729  0.005496
# 2019-04-16                     0.007532                0.009731  0.005760
# 2019-04-17                     0.007574                0.009485  0.006229
# 2019-04-18                     0.007328                0.009475  0.005834
# 2019-04-22                     0.006197                0.009104  0.005831
#
#               Algo 2  SP500Daily  TSLA_Close  GOOG_Close  UAL_Close
# DateTime
# 2019-04-15  0.007572    0.006532    0.026790    0.009922   0.012798
# 2019-04-16  0.007053    0.006571    0.026998    0.009941   0.012475
# 2019-04-17  0.007165    0.006505    0.026999    0.009739   0.015891
# 2019-04-18  0.007172    0.006137    0.026576    0.008661   0.015408
# 2019-04-22  0.007113    0.004302    0.027881    0.008829   0.015491

# %%
# plotting rolling std
my_port_Rstd.plot(rot=75,grid=True,title='custum port Rolling STD W=21',xlabel='Portfolio',ylabel='STD')
concat_data_Rstd.plot(rot=75,grid=True,title='concat data Rolling STD W=21',xlabel='Portfolio',ylabel='STD')
# Out:
# <AxesSubplot:title={'center':'concat data Rolling STD W=21'}, xlabel='Portfolio', ylabel='STD'>

# %%
# rolling covariance of SP500 and custom portfolio
rollingCov1 = Concat_data['SP500Daily'].rolling(60).cov(Concat_data['TSLA_Close'])
rollingCov2 = Concat_data['SP500Daily'].rolling(60).cov(Concat_data['GOOG_Close'])
rollingCov3 = Concat_data['SP500Daily'].rolling(60).cov(Concat_data['UAL_Close'])

rollingCov1.tail()
# Out:
# DateTime
# 2019-04-15   -0.000050
# 2019-04-16   -0.000014
# 2019-04-17   -0.000014
# 2019-04-18   -0.000014
# 2019-04-22   -0.000008
# dtype: float64

# %%
# Rolling variance of SP500
rolling_var_SP = Concat_data['SP500Daily'].rolling(60).var()
rolling_var_SP.tail()
# Out:
# DateTime
# 2019-04-15    0.000041
# 2019-04-16    0.000037
# 2019-04-17    0.000037
# 2019-04-18    0.000037
# 2019-04-22    0.000037
# Name: SP500Daily, dtype: float64

# %%
rolling_beta1 = rollingCov1/rolling_var_SP
rolling_beta2 = rollingCov2/rolling_var_SP
rolling_beta3 = rollingCov3/rolling_var_SP

rolling_beta3.tail()
# Out:
# DateTime
# 2019-04-15   -0.235906
# 2019-04-16   -0.153382
# 2019-04-17   -0.160634
# 2019-04-18   -0.163080
# 2019-04-22   -0.092800
# dtype: float64

# %%
A = rolling_beta1.plot(rot=75,grid=True,title='Beta plot',xlabel='Portfolio',ylabel='Beta')
B = rolling_beta2.plot(rot=75,grid=True)
C = rolling_beta3.plot(rot=75,grid=True)

# %%
#sharpe ratio of the new data
My_sharpe_ratio = (Concat_data.mean()*252 - 0.0025)/(Concat_data.std()*np.sqrt(252))
My_sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.322949
# PAULSON & CO.INC.             -0.513839
# TIGER GLOBAL MANAGEMENT LLC   -0.144638
# BERKSHIRE HATHAWAY INC         0.594552
# Algo 1                         1.348929
# Algo 2                         0.465454
# SP500Daily                    -0.536922
# TSLA_Close                     0.371489
# GOOG_Close                     0.904427
# UAL_Close                      0.356305
# dtype: float64

# %%
# sharpe ratio plot of new data
My_sharpe_ratio.plot(rot=75,grid=True,kind='bar',xlabel='Portfolio',ylabel='Sharpe Ratio')
# Out:
# <AxesSubplot:xlabel='Portfolio', ylabel='Sharpe Ratio'>

# %% [markdown]
# ###### GOOG and UAL outperformed Whale portfolio and all out performed S&P

# %%
Concat_data.mean()
# Out:
# SOROS FUND MANAGEMENT LLC      0.000171
# PAULSON & CO.INC.             -0.000217
# TIGER GLOBAL MANAGEMENT LLC   -0.000089
# BERKSHIRE HATHAWAY INC         0.000494
# Algo 1                         0.000658
# Algo 2                         0.000254
# SP500Daily                    -0.000281
# TSLA_Close                     0.000665
# GOOG_Close                     0.000865
# UAL_Close                      0.000482
# dtype: float64
